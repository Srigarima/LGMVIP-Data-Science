# %% [markdown]
# <a href="https://colab.research.google.com/github/Srigarima/LGMVIP-Data-Science/blob/main/task-04/Stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
db = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
dataset_train = pd.read_csv(db)
train_set = dataset_train.iloc[:, 1:2].values
dataset_train.head(10)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
# 5  2018-09-21  235.00  237.00  227.95  233.75  234.60               5395319
# 6  2018-09-19  235.95  237.20  233.45  234.60  234.90               1362058
# 7  2018-09-18  237.90  239.25  233.50  235.50  235.05               2614794
# 8  2018-09-17  233.15  238.00  230.25  236.40  236.60               3170894
# 9  2018-09-14  223.45  236.70  223.30  234.00  233.95               6377909
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55
# 5         12589.59
# 6          3202.78
# 7          6163.70
# 8          7445.41
# 9         14784.50

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
train_set_scale = scaler.fit_transform(train_set)

# %%
a_train = []
b_train = []
for i in range(60, 2035):
    a_train.append(train_set_scale[i-60:i, 0])
    b_train.append(train_set_scale[i, 0])
a_train, b_train = np.array(a_train), np.array(b_train)

a_train = np.reshape(a_train, (a_train.shape[0], a_train.shape[1], 1))

# %%
model = Sequential()

model.add(LSTM(units=50,return_sequences=True,input_shape=(a_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mean_squared_error')

model.fit(a_train,b_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 15s 120ms/step - loss: 0.0124
# Epoch 2/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0031
# Epoch 3/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0029
# Epoch 4/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0027
# Epoch 5/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0023
# Epoch 6/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0023
# Epoch 7/100
# 62/62 [==============================] - 8s 128ms/step - loss: 0.0020
# Epoch 8/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0019
# Epoch 9/100
# 62/62 [==============================] - 7s 119ms/step - loss: 0.0018
# Epoch 10/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0021
# Epoch 11/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0019
# Epoch 12/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0017
# Epoch 13/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0018
# Epoch 15/100
# 62/62 [==============================] - 9s 138ms/step - loss: 0.0016
# Epoch 16/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0016
# Epoch 17/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0015
# Epoch 18/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0016
# Epoch 19/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0014
# Epoch 20/100
# 62/62 [==============================] - 7s 119ms/step - loss: 0.0017
# Epoch 21/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0015
# Epoch 22/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0014
# Epoch 23/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0013
# Epoch 24/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 25/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0013
# Epoch 26/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0012
# Epoch 27/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0012
# Epoch 28/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0013
# Epoch 29/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0012
# Epoch 30/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0012
# Epoch 31/100
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0012
# Epoch 32/100
# 62/62 [==============================] - 8s 125ms/step - loss: 0.0010
# Epoch 33/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0012
# Epoch 34/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0011
# Epoch 35/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.9683e-04
# Epoch 36/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0012
# Epoch 37/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.7657e-04
# Epoch 38/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.8730e-04
# Epoch 39/100
# 62/62 [==============================] - 7s 121ms/step - loss: 9.7002e-04
# Epoch 40/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0011
# Epoch 41/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 42/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.5477e-04
# Epoch 43/100
# 62/62 [==============================] - 7s 120ms/step - loss: 8.9779e-04
# Epoch 44/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0010
# Epoch 45/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.0634e-04
# Epoch 46/100
# 62/62 [==============================] - 8s 122ms/step - loss: 9.3279e-04
# Epoch 47/100
# 62/62 [==============================] - 7s 121ms/step - loss: 9.9862e-04
# Epoch 48/100
# 62/62 [==============================] - 8s 137ms/step - loss: 8.6203e-04
# Epoch 49/100
# 62/62 [==============================] - 8s 121ms/step - loss: 9.2644e-04
# Epoch 50/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.8754e-04
# Epoch 51/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.7289e-04
# Epoch 52/100
# 62/62 [==============================] - 7s 121ms/step - loss: 9.0809e-04
# Epoch 53/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.7986e-04
# Epoch 54/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.6730e-04
# Epoch 55/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.8128e-04
# Epoch 56/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.8094e-04
# Epoch 57/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.4405e-04
# Epoch 58/100
# 62/62 [==============================] - 7s 120ms/step - loss: 8.7366e-04
# Epoch 59/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.7024e-04
# Epoch 60/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.9445e-04
# Epoch 61/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.8087e-04
# Epoch 62/100
# 62/62 [==============================] - 8s 122ms/step - loss: 9.1798e-04
# Epoch 63/100
# 62/62 [==============================] - 8s 123ms/step - loss: 8.4236e-04
# Epoch 64/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.0857e-04
# Epoch 65/100
# 62/62 [==============================] - 9s 137ms/step - loss: 7.0134e-04
# Epoch 66/100
# 62/62 [==============================] - 7s 121ms/step - loss: 7.4128e-04
# Epoch 67/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.9795e-04
# Epoch 68/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.2588e-04
# Epoch 69/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.6372e-04
# Epoch 70/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.9557e-04
# Epoch 71/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.3322e-04
# Epoch 72/100
# 62/62 [==============================] - 8s 121ms/step - loss: 6.8463e-04
# Epoch 73/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.4107e-04
# Epoch 74/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.4404e-04
# Epoch 75/100
# 62/62 [==============================] - 8s 123ms/step - loss: 7.1342e-04
# Epoch 76/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.3447e-04
# Epoch 77/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.6256e-04
# Epoch 78/100
# 62/62 [==============================] - 8s 123ms/step - loss: 8.3050e-04
# Epoch 79/100
# 62/62 [==============================] - 8s 123ms/step - loss: 7.3795e-04
# Epoch 80/100
# 62/62 [==============================] - 8s 121ms/step - loss: 6.7876e-04
# Epoch 81/100
# 62/62 [==============================] - 9s 139ms/step - loss: 6.0131e-04
# Epoch 82/100
# 62/62 [==============================] - 8s 123ms/step - loss: 7.7955e-04
# Epoch 83/100
# 62/62 [==============================] - 8s 122ms/step - loss: 5.9993e-04
# Epoch 84/100
# 62/62 [==============================] - 8s 122ms/step - loss: 8.9673e-04
# Epoch 85/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.6582e-04
# Epoch 86/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.1942e-04
# Epoch 87/100
# 62/62 [==============================] - 8s 123ms/step - loss: 7.4179e-04
# Epoch 88/100
# 62/62 [==============================] - 8s 122ms/step - loss: 8.5385e-04
# Epoch 89/100
# 62/62 [==============================] - 7s 121ms/step - loss: 6.2489e-04
# Epoch 90/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.1528e-04
# Epoch 91/100
# 62/62 [==============================] - 8s 121ms/step - loss: 5.4307e-04
# Epoch 92/100
# 62/62 [==============================] - 8s 121ms/step - loss: 6.2103e-04
# Epoch 93/100
# 62/62 [==============================] - 7s 119ms/step - loss: 6.0548e-04
# Epoch 94/100
# 62/62 [==============================] - 8s 122ms/step - loss: 5.0111e-04
# Epoch 95/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.3233e-04
# Epoch 96/100
# 62/62 [==============================] - 7s 121ms/step - loss: 6.3053e-04
# Epoch 97/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.2621e-04
# Epoch 98/100
# 62/62 [==============================] - 9s 138ms/step - loss: 6.1476e-04
# Epoch 99/100
# 62/62 [==============================] - 8s 122ms/step - loss: 5.5602e-04
# Epoch 100/100
# 62/62 [==============================] - 8s 121ms/step - loss: 6.4887e-04

# %%
db = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/tatatest.csv'
dataset_test = pd.read_csv(db)
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

# %%
plt.plot(real_stock_price, color = 'orange', label = 'TATA Stock Price')
plt.plot(predicted_stock_price, color = 'brown', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
